# %% [markdown]
# <a href="https://colab.research.google.com/github/Mbashas/SecondYear/blob/main/KOPESHA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KOPESHA** LOAN

# %% [markdown]
# ![Screenshot 2023-11-13 184911.png](data:image/png;base64,...)

# %%
                        ################################################################################################################################
                        #                                                                                                                              #
                        #                                                     SECTION ONE : THE OOP CODE                                               #
                        #                                                                                                                              #
                        ################################################################################################################################






#FIRST CLASS: THIS IS THE PARENT CLASS

class MainLoan:

    name=None
    age=None
    genre=None
    occupation=None
    loan=None
    Days=None


    def __init__(self,name,age,genre,occupation,loan,Days):

        self.name=name
        self.age=age
        self.genre=genre
        self.occupation=occupation
        self.loan=loan
        self.Days=Days

    def SimpleLoan(self,another_loan):

        MaxDays=30 # past this number of days, the loan is going to be increasing by the fine.
        while True:
            print()
            self.name=input("what is your full name: ")
            self.loan=int(input("enter amount of loan: "))
            self.Days=int(input("Enter days with loan: "))
            if self.Days<=MaxDays:
                interest=self.loan*(10/100)
                payment=self.loan+interest
                print()
                print(f"Dear {self.name.split()[0]} ,after {self.Days} days, you will pay an amount of {payment}")
                print("thank you!!😁")
                print()
                another_loan=input("wanna take another loan? ")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print()
                    break
            else:
                interest=self.loan*(10/100)
                extraDays=self.Days-MaxDays
                TotalFine=extraDays*(self.loan*(1/100))
                payment=self.loan+interest+(TotalFine)
                print(f"because of the extra {extraDays} days, you will be charged a fine of {TotalFine} on top of the interest")
                print()
                print(f"So,Dear {self.name.split()[0]} , after {self.Days} days, you will pay an amount of {payment} which include the {self.loan} of loan , the interest of {interest} plus a fine of {TotalFine}")
                print()
                print("thank you!!😁")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print()
                    break


#SECOND CLASS: FOR STUDENT LOAN

class EduLoan(MainLoan): # here we are inheriting from the base or parent class called "MainLoan"

    level=None

    def __init__(self,name,age,genre,occupation,loan,Days,level):
        self.name=name
        self.age=age
        self.genre=genre
        self.occupation=occupation
        self.loan=loan
        self.Days=Days
        self.level=level

    def SimpleLoan(self,another_loan):

        print()
        print("Hello dear student, this is KOPESHA, the solution to your loan aquisition problems")
        print()

        MaxDays=280 # past this number of days, the loan is going to be increasing by the fine.
                    # the academic year in uganda is arround 240, so we add 40 days to help them
                    # finish paying at the end of the academic year (arround 280 days)
        while True:
            print()
            self.name=input("what is your full name: ")
            self.loan=int(input("enter amount of loan: "))
            self.Days=int(input("Enter days with loan: "))
            self.level=input("level of studies please: ")
            if self.Days<=MaxDays:
                naame=self.name
                interest=self.loan*(10/100)
                payment=self.loan+interest
                print()
                print(f"Dear {naame.strip().lower().split()[0]},After further verification you succesfully got the {self.level} student loan of ${self.loan}, after {self.Days} days, you will pay an amount of ${payment}")
                print("thank you!!😁")
                print()
                another_loan=input("do you want to take another loan? ")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print("We wish you success in your studies, remember, KOPESHA is here to ensure your future")
                    print()
                    break
            else:
                naame=self.name
                interest=self.loan*(10/100)
                extraDays=self.Days-MaxDays
                TotalFine=extraDays*(self.loan*(1/100))
                payment=self.loan+interest+(TotalFine)
                print()
                print(f"hey {naame.strip().lower().split()[0]}, because of the extra {extraDays} days, you will be charged a fine of ${TotalFine} on top of the interest")
                print()
                print(f"So,Dear {self.name.split()[0]} , after {self.Days} days, you will pay an amount of ${payment} which include the ${self.loan} of loan , the interest of ${interest} plus a fine of ${TotalFine}")
                print()
                print("thank you!!😁")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print()
                    break



# THIRD CLASS : FOR BUSINESS LOANS

class BusinessLoan(MainLoan): # here we are inheriting from the base or parent class called "MainLoan"

    business=None
    Livelyhood=None

    def __init__(self,name,age,genre,occupation,loan,Days,business,Livelyhood):
        self.name=name
        self.age=age
        self.genre=genre
        self.occupation=occupation
        self.loan=loan
        self.Days=Days
        self.business=business
        self.Livelyhood=Livelyhood # how old is the business (to see if the project has survived without the loan and we can then act accordingly)

    def SimpleLoan(self,another_loan):

        print()
        print("Hello dear, this is KOPESHA, the solution to your loan aquisition problems")
        print()

        MaxDays=365 # past this number of days, the loan is going to be increasing by the fine.
                    # we are considering 365,
                    # Idealy finish paying at the end of 300 days
        while True:
            print()
            self.name=input("what is your full name: ")
            self.loan=int(input("enter amount of loan: "))
            self.Days=int(input("Enter days with loan: "))
            self.business=input("what is your business: ")
            self.Livelyhood=int(input("for how long (in year) are you holding this business: "))
            if self.Days<=MaxDays:
                naame=self.name
                interest=self.loan*(10/100)
                payment=self.loan+interest
                print()
                print(f"Dear {naame.strip().lower().split()[0]} ,After further verification you succesfully got the special business loan of ${self.loan}, after {self.Days} days, you will pay back an amount of ${payment}")
                print("thank you!!😁")
                print()
                another_loan=input("do you want to take another loan? ")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print("We wish you success in your Business, remember, KOPESHA is here to ensure the success of your business")
                    print()
                    break
            else:
                naame=self.name
                interest=self.loan*(10/100)
                extraDays=self.Days-MaxDays
                TotalFine=extraDays*(self.loan*(1/100))
                payment=self.loan+interest+(TotalFine)
                print()
                print(f"hey {naame.strip().lower().split()[0]}, because of the extra {extraDays} days, you will be charged a fine of ${TotalFine} on top of the interest")
                print()
                print(f"So,Dear {self.name.split()[0]} , after {self.Days} days, you will pay an amount of ${payment} which include the ${self.loan} of loan , the interest of ${interest} plus a fine of ${TotalFine}")
                print()
                print("thank you!!😁")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print()
                    break


# FOURTH CLASS: FOR HEALTH INSURENCE LOAN

class HealthLoan(MainLoan):

    disease=None
    levelOfRisk=None


    def __init__(self,name,age,genre,occupation,loan,Days,disease,levelOfRisk):

        self.name=name
        self.age=age
        self.genre=genre
        self.occupation=occupation
        self.loan=loan
        self.Days=Days
        self.disease=disease
        self.levelOfRisk=levelOfRisk


    def SimpleLoan(self,another_loan):

        MaxDays=540 # past this number of days, the loan is going to be increasing by the fine.
                    # here we are using 500 because, this is specially for health, we want them to pay
                    # by spreading the money through 18 months (a year and a half)
        while True:
            print()
            self.name=input("what is your full name: ")
            self.loan=int(input("enter amount of loan: "))
            self.Days=int(input("Enter days with loan: "))
            self.disease=input("what was the disease diagnostiqued by your doctor: ")
            self.levelOfRisk=int(input("according to your doctor,on a scale of 10, what is the level of risk related to the disease ?: "))

            if self.Days<=MaxDays:
                interest=self.loan*(10/100)
                payment=self.loan+interest
                print()
                print(f"Dear {self.name.split()[0]} ,your request for the special healthcare loan is APROVED !!, this is based on the fact that we've studied the special case of your disease,which is at level {self.levelOfRisk}/10. So after {self.Days} days, you will pay an amount of {payment}")
                print("We thank you for the trust in us, and KOPESHA wishes you a quick recovery!!😁")
                print()
                another_loan=input("wanna take another loan? ")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US AND QUICK RECOVERY!!!")
                    print()
                    print("                       KOPESHA                  ")
                    break
            else:
                interest=self.loan*(10/100)
                extraDays=self.Days-MaxDays
                TotalFine=extraDays*(self.loan*(1/100))
                payment=self.loan+interest+(TotalFine)
                print(f"Hey mrs/ms {self.name.split()[0],}because of the extra {extraDays} days, you will be charged a fine of {TotalFine} on top of the interest, this is just in case the loan is not payed in time")
                print()
                print(f"So,Dear {self.name.split()[0]} , after {self.Days} days, you will pay an amount of {payment} which include the {self.loan} of loan , the interest of {interest} plus a fine of {TotalFine}")
                print()
                print("thank you!!😁")

                if another_loan=="yes" or another_loan=="Yes" or another_loan=="YES":
                    continue
                else:
                    print("THANK YOU FOR TRUSTING US!!!")
                    print()
                    break




                      ################################################################################################################################
                      #                                                                                                                              #
                      #                                              SECTION TWO : OBJECT CREATION                                                   #
                      #                                                                                                                              #
                      ################################################################################################################################




BusinessObject=BusinessLoan(None,None,None,None,None,None,None,None) # 8 values since we have initiated 8 variables in 3rd class
StudentObject=EduLoan(None,None,None,None,None,None,None) # 7 values since we have initiated 7 variables in 2nd class
HealthObject=HealthLoan(None,None,None,None,None,None,None,None) # 8 values since we have initiated 8 variables in 4th class



                      ################################################################################################################################
                      #                                                                                                                              #
                      #                                               SECTION THREE: CODE LAUNCHING                                                  #
                      #                                                                                                                              #
                      ################################################################################################################################


def TheLoan():
    State=input("who are you: STUDENT, PATIENT OR BUSINES_OWNER: ")
    if State=="student" or State=="Student" or State=="STUDENT":
        StudentObject.SimpleLoan(None)
    elif State=="Businessowner" or State=="businessowner" or State=="BUSINESSOWNER":
        BusinessObject.SimpleLoan(None)
    elif State=="Patient" or State=="patient" or State=="PATIENT":
        HealthObject.SimpleLoan(None)
    else: # the more classes we create, the more elif statements we will add here for each specific class
        print("you're not a STUDENT or a BUSINESS OWNER,KINDLY WAIT FOR YOUR TURN TO START")

TheLoan()


                      ################################################################################################################################
                      #                                                                                                                              #
                      #                               SECTION FOUR: USED AS A TO.DO LIST FOR THE DIFFERENT UPDATES THAT WILL BE DONE                 #
                      #                                                                                                                              #
                      ################################################################################################################################

# %% [markdown]
# ##POSSIBLE IMPROVEMENTS, REQUIREMENTS AND UPDATES DISCOVERED SO FAR 🎯:
#
# - IMPLEMENTATION OF POLICIES REGARDING EACH OF THE SERVICES WE AIM TO PROVIDE
# - SPECIFICATION OF THE REAL TIME DATE IN ORDER TO IMPLEMENT FEATURES LIKE PAYMENT TRACKING, REMINDERS,SCHEDULING, CALENDAR Etc
# - ACCOUNT CREATION FOR MORE DYNAMISM AND CONSISTENCY, BUT ALSO FOR MORE REALISTIC SERVICE (LIKE IN THE REAL WORLD)
# - IMPLEMENTATION OF A REAL TIME CURRENCY CONVERTER SO THAT ANYONE FROM ANY COUNTRY WITH ANY MONEY CURRENCY CAN BE SERVED,
# - WITH THIS COMES IN THE DIFFERENT SYNCHRONIZATION THAT WILL BE DONE BETWEEN US AND THE DIFFERENT BANK ACCOUNTS, BUT ALSO MOBILE MONEY ACCOUNTS DEPEMDING ON THE CUSTOMERS NEED AND ALSO DEPENDING ON THE AMMOUNT NEEDED
# - SECURITY UPDATES: REGISTRATION WITH PASSWORD, NAME, GENRE, AND OTHER APPROPRIED REQUIREMENT FOR SUCH SERVICE (THIS WILL BE ADDED OVER TIME AS WE ARE LEARNING HOW THE LOAN PROCESS IS DONE IN THE FIELD)
# - FRONT-END DEVELLOPMENT OF THE APP AFTER THE BACK-END IMPLEMENTATION (THIS WILL COME IN LATER AS WE ARE GETING MORE AND MORE EXPERIENCE WITH WEB AND MOBILE DEVELLOPMENT)
# - ALL THE NUMBERS USED IN THIS PROGRAM ARE FOR THE DEVELLOPMENT PURPOSE, THEY WILL ALL BEING CHANGED AT THE BUSINESS MODEL UPDATING STAGE,
# -ALSO, SINCE OUR GOAL IS TO PROVIDE MORE FLEXIBLE SERVICES, WE NEED TO REVIEW OUR CHARGING RATE, OUR PAYEMENT POLICY, OUR RISK MITIGATION AND A LOT OF OTHER THINGS TO BE TAKEN INTO CONSIDERATION.
#
#
#
# NOTE: THERE ARE STILL SO MANY UPDATES TO BE DONE AND WE ARE DISCOVERING THEM MORE AND MORE AS WE ARE GOING DEEP INTO THE LEARNING PROCESS OF:
#
#  - THE LOAN SERVICE BUSINESS MODEL
#  -  LOAN POLICIES,
#  -  LOAN SERVICES NORMS
#  -  RULES, CONDITIONS AND TERMS
#  -  TECHNIQUES, METHODS.
#
#
#
#  *With that you can tell that we have a lot of work to do before we call it a "real" and "working" project. But we are going to fulfill these previous objectives as we are going to be learning day by day because this can definittely not been done in one month or two, also is even more complex as we though but VERY interesting to work on !*
#
#  So, with that said, we can tell that we've done the fundation of the whole idea, and the remaining work is the optimisation of the idea in order to fit in all the requirements for it to provide the expected service.
